# %%
cd drive/MyDrive/AVE/BERT_multimodal_transformer/
# Out:
# /content/drive/MyDrive/AVE/BERT_multimodal_transformer

# %%
# !pip install torch torchvision torchaudio numpy pandas wandb scikit-learn transformers tensorflow -q

# %%
# !python multimodal_driver.py --model bert-base-uncased --dataset custom_dataset/split_ave_dataset_bert --max_seq_length 256

# %%
label_count = {"Clothing": 30,
              "Footwear": 32,
              "General": 25}

# %%
for subset in ["Clothing", "Footwear", "General"]:
  for shot in [5,10,15,25,50,100,1000]:
    dataset_name = f'custom_dataset/bert_{subset}_{shot}_shot'
    labels = label_count[subset]

    # !python multimodal_driver.py --model bert-base-uncased --dataset {dataset_name} --max_seq_length 256 --num_labels {labels}
    print(f'Done on {subset} at {shot} shot')
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch:1, train_loss:3.401357957295009, valid_loss:3.401553213596344, test_acc:0.042926829268292686
# Iteration:   0% 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:907: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Iteration: 100% 7/7 [00:02<00:00,  2.39it/s]
# Iteration: 100% 24/24 [00:08<00:00,  2.70it/s]
# 100% 25/25 [00:09<00:00,  2.70it/s]
# epoch:2, train_loss:3.4011185509817943, valid_loss:3.401495228211085, test_acc:0.05008130081300813
# Iteration:   0% 0/7 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:907: FutureWarning: The `device` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# Iteration: 100% 7/7 [00:02<00:00,  2.39it/s]
# Iteration: 100% 24/24 [00:08<00:00,  2.70it/s]
# 100% 25/25 [00:09<00:00,  2.70it/s]
# ...
